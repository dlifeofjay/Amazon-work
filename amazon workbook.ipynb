# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('amazon_sales_data 2025.csv')
df.head()
# Out:
#   Order ID      Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-25     Headphones  Electronics    100         4
# 2  ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-25     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
df.Product.unique()
# Out:
# array(['Running Shoes', 'Headphones', 'Smartwatch', 'T-Shirt',
#        'Smartphone', 'Book', 'Jeans', 'Laptop', 'Washing Machine',
#        'Refrigerator'], dtype=object)

# %%
df['Total Sales'].min(), df['Total Sales'].max()
# Out:
# (np.int64(15), np.int64(6000))

# %%
df['Payment Method'].unique()
# Out:
# array(['Debit Card', 'Amazon Pay', 'Credit Card', 'PayPal', 'Gift Card'],
#       dtype=object)

# %%
df.Status.unique()
# Out:
# array(['Cancelled', 'Pending', 'Completed'], dtype=object)

# %%
df['Customer Location'].unique()
# Out:
# array(['New York', 'San Francisco', 'Denver', 'Dallas', 'Houston',
#        'Miami', 'Boston', 'Seattle', 'Los Angeles', 'Chicago'],
#       dtype=object)

# %%
df.

# %%
df.Category.unique()
# Out:
# array(['Footwear', 'Electronics', 'Clothing', 'Books', 'Home Appliances'],
#       dtype=object)

# %%
df_prod = df.groupby('Product').sum(numeric_only=True)
plt.figure(figsize=(12, 6))
sns.barplot(data=df_prod, x='Product', y='Total Sales')
plt.xlabel('Product')
plt.ylabel('Total Revenue')
plt.title('Products vs Revenue')
plt.xticks(rotation=45)
plt.savefig('Products and Total Revenue Earned', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_ref = df[df['Product'] == 'Refrigerator']
plt.figure(figsize=(12,6))
sns.countplot(data=df_ref, x='Customer Location', hue='Product')
plt.xlabel('Customer City')
plt.ylabel('Number of Refrigerator')
plt.title('Cities and Number of Refrigerator Purchased')
plt.savefig('Cities and Number of Refrigerator Purchased', dpi=300, bbox_inches='tight')
plt.plot()
# Out:
# []

# %%
color=['red', 'blue', 'purple', 'black', 'green']
df_group = df.groupby('Category').sum(numeric_only=True)
plt.figure(figsize=(12,6))
sns.barplot(hue='Category', y='Total Sales', data=df_group, palette=color)
plt.xlabel('Product Category')
plt.ylabel('Revenue')
plt.title('Category vs Revenue')
plt.xticks(rotation=45)
plt.savefig("Category vs Revenue.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.savefig("Category vs Revenue.png", dpi=300, bbox_inches='tight')

# %%
df_elect = df[df['Category'] == 'Electronics']
df_cat = df_elect.groupby('Product').sum(numeric_only=True)
df_cat['Total Sales'].plot(kind='bar', figsize=(12,6))
plt.xlabel('Products')
plt.ylabel('Revenue')
plt.title('Product with the Highest Categorical Sales')
plt.xticks(rotation=45)
plt.savefig('Product with the Highest Categorical Sales.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Category', hue='Customer Location', data=df)
plt.xlabel('Category')
plt.ylabel('Customer Count')
plt.title('Customers Location for each Category')
plt.xticks(rotation=45)
plt.savefig('Customers Location for each Category.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_elect = df[df['Category'] == 'Electronics']
plt.figure(figsize=(12, 6))
sns.countplot(data=df_elect, x='Product', hue='Customer Location')
plt.xlabel('Product')
plt.ylabel('Customer Location')
plt.title('Cities and Electronics Purchased')
plt.xticks(rotation=45)
plt.savefig('Cities and Electronics Purchased', dpi=300, bbox_inches='tight')
plt.show()

# %%
df.head()
# Out:
#   Order ID      Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-25     Headphones  Electronics    100         4
# 2  ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-25     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Payment Method', hue='Status', data=df)
plt.xlabel('Payment Method')
plt.ylabel('Transaction Status Count')
plt.title('Status Count on Payment Method')
plt.xticks(rotation=45)
plt.savefig('Status Count on Payment Method', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_count = df['Status'].value_counts()

# %%
plt.figure(figsize=(8,8))
plt.pie(df_count, labels=df_count.index, autopct='%1.1f%%', startangle=140, colors=['green', 'orange', 'blue'])
plt.title('Pay Method Distribution')
plt.savefig('Pay Method Distribution', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_filt = df[df['Status'].isin(['Cancelled', 'Pending'])]
plt.figure(figsize=(12, 6))
sns.countplot(data=df_filt, x='Category', hue='Status')
plt.xlabel('Category')
plt.ylabel('Transaction Status')
plt.title('Product Categories with Uncompleted Payment')
plt.savefig('Product Categories with Uncompleted Payment', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_com = df[df['Status'] == 'Completed']
plt.figure(figsize=(12, 6))
sns.countplot(data=df_com, x='Category', hue='Status')
plt.xlabel('Category')
plt.ylabel('Transaction Status')
plt.title('Product Categories with Completed Payment')
plt.savefig('Product Categories with Completed Payment', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.countplot(data=df, x='Customer Location', hue='Status')
plt.xlabel('Customer Location')
plt.ylabel('Transaction Status')
plt.title('Cities with Transaction Status')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.countplot(data=df, x='Customer Location', hue='Payment Method')
plt.xlabel('Customer Location')
plt.ylabel('Payment Method')
plt.title('Cities vs Payment Method')
plt.xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#   Order ID      Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-25     Headphones  Electronics    100         4
# 2  ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-25     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
df= df.filter(['Product', 'Category', 'Total Sales', 'Customer Location', 'Payment Method', 'Status'], axis=1)
df
# Out:
#            Product     Category  Total Sales Customer Location Payment Method  \
# 0    Running Shoes     Footwear          180          New York     Debit Card
# 1       Headphones  Electronics          400     San Francisco     Debit Card
# 2    Running Shoes     Footwear          120            Denver     Amazon Pay
# 3    Running Shoes     Footwear          180            Dallas    Credit Card
# 4       Smartwatch  Electronics          450          New York     Debit Card
# ..             ...          ...          ...               ...            ...
# 245        T-Shirt     Clothing           40             Miami     Debit Card
# 246          Jeans     Clothing           40            Dallas     Debit Card
# 247        T-Shirt     Clothing           40            Denver     Debit Card
# 248     Smartwatch  Electronics          450          New York     Debit Card
# 249     Smartphone  Electronics         2000           Seattle     Amazon Pay
#
#         Status
# 0    Cancelled
# ...

# %%
from collections import Counter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           250 non-null    object
#  1   Date               250 non-null    object
#  2   Product            250 non-null    object
#  3   Category           250 non-null    object
#  4   Price              250 non-null    int64
#  5   Quantity           250 non-null    int64
#  6   Total Sales        250 non-null    int64
#  7   Customer Name      250 non-null    object
#  8   Customer Location  250 non-null    object
#  9   Payment Method     250 non-null    object
#  10  Status             250 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.6+ KB

# %%
count = Counter(df['Status'])
count
# Out:
# Counter({'Completed': 88, 'Pending': 85, 'Cancelled': 77})

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import LabelEncoder

# %%
cols = []

for i in df.columns:
    if df[i].dtype == 'object':
        cols.append(i)

# %%
le=LabelEncoder()
cols
# Out:
# ['Order ID',
#  'Date',
#  'Product',
#  'Category',
#  'Customer Name',
#  'Customer Location',
#  'Payment Method',
#  'Status']

# %%
for col in cols:
    df[col]=le.fit_transform(df[col])
    print(le.classes_)
# Out:
# ['ORD0001' 'ORD0002' 'ORD0003' 'ORD0004' 'ORD0005' 'ORD0006' 'ORD0007'
#  'ORD0008' 'ORD0009' 'ORD0010' 'ORD0011' 'ORD0012' 'ORD0013' 'ORD0014'
#  'ORD0015' 'ORD0016' 'ORD0017' 'ORD0018' 'ORD0019' 'ORD0020' 'ORD0021'
#  'ORD0022' 'ORD0023' 'ORD0024' 'ORD0025' 'ORD0026' 'ORD0027' 'ORD0028'
#  'ORD0029' 'ORD0030' 'ORD0031' 'ORD0032' 'ORD0033' 'ORD0034' 'ORD0035'
#  'ORD0036' 'ORD0037' 'ORD0038' 'ORD0039' 'ORD0040' 'ORD0041' 'ORD0042'
#  'ORD0043' 'ORD0044' 'ORD0045' 'ORD0046' 'ORD0047' 'ORD0048' 'ORD0049'
#  'ORD0050' 'ORD0051' 'ORD0052' 'ORD0053' 'ORD0054' 'ORD0055' 'ORD0056'
#  'ORD0057' 'ORD0058' 'ORD0059' 'ORD0060' 'ORD0061' 'ORD0062' 'ORD0063'
#  'ORD0064' 'ORD0065' 'ORD0066' 'ORD0067' 'ORD0068' 'ORD0069' 'ORD0070'
#  'ORD0071' 'ORD0072' 'ORD0073' 'ORD0074' 'ORD0075' 'ORD0076' 'ORD0077'
#  'ORD0078' 'ORD0079' 'ORD0080' 'ORD0081' 'ORD0082' 'ORD0083' 'ORD0084'
#  'ORD0085' 'ORD0086' 'ORD0087' 'ORD0088' 'ORD0089' 'ORD0090' 'ORD0091'
# ...

# %%
X=df.drop(['Status'], axis=1)
y=df['Status']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=30)

# %%
ros = RandomOverSampler(random_state=30)
X_resample, y_resample = ros.fit_resample(X_train, y_train)

# %%
len(X_resample), len(y_resample)
# Out:
# (186, 186)

# %%
X=X_resample
y=y_resample

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=30)

# %%
model=RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_train, y_train)
# Out:
# 0.9594594594594594

# %%
y_pred=model.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay

# %%
acc = accuracy_score(y_train, y_pred)
acc
# Out:
# 0.9594594594594594

# %%
ConfusionMatrixDisplay.from_predictions(y_train, y_pred)

# %%
import pickle

# %%
with open('amazon_mod.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('amazon_le.pkl', 'wb') as f:
    pickle.dump(le, f)
